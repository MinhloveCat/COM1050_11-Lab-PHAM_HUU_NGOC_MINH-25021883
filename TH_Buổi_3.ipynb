# %%
xuoi = input("Nhập một số nguyên n: ")
nguoc = xuoi[::-1]
print(nguoc)
# Out:
# Nhập một số nguyên n: 1
# 1

# %%
a,b = map(int,input().split())
#gs a = A , b = B
a = a^b # a = A^B
b = a^b # b = (A^B)^B --> b = A
a = a^b # a = (A^B)^A = (A^A)^B --> a = B
print(a,b)
# Out:
# 5 5
# 5 5

# %%
num = int(input())
if num & (num-1) == 0 and num > 0:
  print('True')
else:
  print('False')
# Out:
# 64
# True

# %%
m,n = map(int, input().split())
thuong = m/n
down = int(thuong)
print(down)
# Out:
# 2442 2
# 1221

# %%
m,n = map(int, input().split())
thuong = m/n
up = int(thuong) + (m%n != 0)
print(up)
# Out:
# 7553 764
# 10

# %%
num = int(input())
if num % 2 == 0:
  print('Even')
else:
  print('Odd')
# Out:
# 6
# Even

# %%
a,b = map(int, input().split())
if a < 0 and b <0:
  print('Yes')
else:
  print('No')
# Out:
# -121 -12
# Yes

# %%
a = input()
b = input()
if len(a) > len(b):
 print('True')
else:
  print('False')
# Out:
# aaaaa
# cdefg
# False

# %%
a,b,c = map(int, input().split())
if a+b > c and a+c > b and b+c >a:
  print('True')
else:
  print('False')
# Out:
# 16 25 9
# False
# False

# %%
a,b,c,d = map(int, input().split())
Max = max(a,b,c,d)
print(Max)
# Out:
# 9999 999 99 9
# 9999

# %%
a,b,c = map(int, input().split())
if a+b > c and a+c > b and b+c >a:
  if a == b == c:
    print('Tam giác đều')
  elif a == b != c or a == c != b or a != b == c:
    print('Tam giác cân')
  else:
    print('Tam giác thường')
else:
  print('Không phải tam giác')
# Out:
# 0 0 0
# Không phải tam giác

# %%
year = int(input())
if (year % 4 == 0 and year % 100 != 0) or year%400==0:
  print('Yes')
else:
  print('No')
# Out:
# 2024
# Yes

# %%
so_dien = int(input())
tien_dien = 0
if 0< so_dien <=50:
  tien_dien = so_dien*1500
elif so_dien <= 100:
  tien_dien = 50*1500 + (so_dien - 50)*2000
else:
  tien_dien = 50*1500 + 50*2000 + (so_dien - 100)*3000
print(tien_dien)
# Out:
# 100
# 175000

# %%
a,b = map(float,input().split())
if a != 0:
  if b == 0:
    print('Vô số nghiệm')
  else:
    print(f'Nghiệm của phương trình là {round(-b/a, 2)}')
else:
  if b == 0:
    print('Vô số nghiệm')
  else:
    print('Vô nghiệm')
# Out:
# 0.23 99.1
# Nghiệm của phương trình là -430.87

# %%
score = float(input())
if score >= 8:
  print('Giỏi')
elif score >= 6.5:
  print('Khá')
elif score >= 5.0:
  print('Trung bình')
else:
  print('Yếu')
# Out:
# 8
# Giỏi

# %%
#True = 1; False = 0
x = float(input())
if x >= 0:
    down = int(x)
else:
    down = int(x) - (x != int(x))
if x >= 0:
    up = int(x) + (x != int(x))
else:
    up = int(x)
decimal = x - int(x)
if x >= 0:
    nearest = int(x) + (decimal >= 0.5)
else:
    nearest = int(x) - (decimal <= -0.5)
print(up, down, nearest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1363275264.py in <cell line: 0>()
# ----> 1 x = float(input())
#       2 if x >= 0:
#       3     down = int(x)
#       4 else:
#       5     down = int(x) - (x != int(x))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
a,b,c = map(int, input().split())
if a+b > c and a+c > b and b+c >a:
  if a == b == c:
    print('Tam giác đều')
  elif a == b != c or a == c != b or a != b == c:
    print('Tam giác cân')
  else:
    print('Tam giác thường')
else:
  print('Không phải tam giác')
# Out:
# 2
